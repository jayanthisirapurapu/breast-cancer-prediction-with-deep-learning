# %%
# importing required libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load the dataset
df = pd.read_csv('/content/drive/MyDrive/Ai/House Price India.csv')
df.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %%
df.tail()
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 14615  6762830250  42734                   2                  1.5
# 14616  6762830339  42734                   3                  2.0
# 14617  6762830618  42734                   2                  1.0
# 14618  6762830709  42734                   4                  1.0
# 14619  6762831463  42734                   3                  1.0
#
#        living area  lot area  number of floors  waterfront present  \
# 14615         1556     20000               1.0                   0
# 14616         1680      7000               1.5                   0
# 14617         1070      6120               1.0                   0
# 14618         1030      6621               1.0                   0
# 14619          900      4770               1.0                   0
#
#        number of views  condition of the house  ...  Built Year  \
# 14615                0                       4  ...        1957
# ...

# %%
df.shape
# Out:
# (14620, 23)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14620 entries, 0 to 14619
# Data columns (total 23 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     14620 non-null  int64
#  1   Date                                   14620 non-null  int64
#  2   number of bedrooms                     14620 non-null  int64
#  3   number of bathrooms                    14620 non-null  float64
#  4   living area                            14620 non-null  int64
#  5   lot area                               14620 non-null  int64
#  6   number of floors                       14620 non-null  float64
#  7   waterfront present                     14620 non-null  int64
#  8   number of views                        14620 non-null  int64
#  9   condition of the house                 14620 non-null  int64
# ...

# %%
df.isnull().any()
# Out:
# id                                       False
# Date                                     False
# number of bedrooms                       False
# number of bathrooms                      False
# living area                              False
# lot area                                 False
# number of floors                         False
# waterfront present                       False
# number of views                          False
# condition of the house                   False
# grade of the house                       False
# Area of the house(excluding basement)    False
# Area of the basement                     False
# Built Year                               False
# Renovation Year                          False
# Postal Code                              False
# Lattitude                                False
# Longitude                                False
# living_area_renov                        False
# lot_area_renov                           False
# ...

# %%
df.describe()
# Out:
#                  id          Date  number of bedrooms  number of bathrooms  \
# count  1.462000e+04  14620.000000        14620.000000         14620.000000
# mean   6.762821e+09  42604.538646            3.379343             2.129583
# std    6.237575e+03     67.347991            0.938719             0.769934
# min    6.762810e+09  42491.000000            1.000000             0.500000
# 25%    6.762815e+09  42546.000000            3.000000             1.750000
# 50%    6.762821e+09  42600.000000            3.000000             2.250000
# 75%    6.762826e+09  42662.000000            4.000000             2.500000
# max    6.762832e+09  42734.000000           33.000000             8.000000
#
#         living area      lot area  number of floors  waterfront present  \
# count  14620.000000  1.462000e+04      14620.000000        14620.000000
# mean    2098.262996  1.509328e+04          1.502360            0.007661
# std      928.275721  3.791962e+04          0.540239            0.087193
# ...

# %%
df.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %%
df.id.unique()
# Out:
# array([6762810145, 6762810635, 6762810998, ..., 6762830618, 6762830709,
#        6762831463])

# %%
df.Longitude.value_counts()
# Out:
# -114.552    73
# -114.562    73
# -114.490    72
# -114.480    69
# -114.553    68
#             ..
# -114.036     1
# -114.096     1
# -113.994     1
# -114.111     1
# -113.891     1
# Name: Longitude, Length: 716, dtype: int64

# %%
df.Lattitude.value_counts()
# Out:
# 52.7745    13
# 52.8947    13
# 52.9255    13
# 52.9146    13
# 52.8834    13
#            ..
# 52.8969     1
# 52.6834     1
# 52.5337     1
# 52.6155     1
# 52.5338     1
# Name: Lattitude, Length: 4662, dtype: int64

# %%
df.id.value_counts()
# Out:
# 6762810145    1
# 6762812541    1
# 6762813736    1
# 6762813785    1
# 6762814009    1
#              ..
# 6762812356    1
# 6762812410    1
# 6762812471    1
# 6762812563    1
# 6762831463    1
# Name: id, Length: 14620, dtype: int64

# %%
df.corr()
# Out:
#                                              id      Date  number of bedrooms  \
# id                                     1.000000  0.045966           -0.329034
# Date                                   0.045966  1.000000           -0.015663
# number of bedrooms                    -0.329034 -0.015663            1.000000
# number of bathrooms                   -0.516909 -0.026485            0.509784
# living area                           -0.648127 -0.021958            0.570526
# lot area                              -0.100269  0.004392            0.034416
# number of floors                      -0.312305 -0.010335            0.177294
# waterfront present                    -0.112937  0.012006           -0.006257
# number of views                       -0.293004 -0.004782            0.078665
# condition of the house                -0.045061 -0.027402            0.026597
# grade of the house                    -0.673448 -0.033097            0.352945
# ...

# %% [markdown]
# # **Visualization**

# %% [markdown]
# # Univariate **Analysis**

# %%
sns.distplot(df.Price)
# Out:
# <ipython-input-27-5e080168c38c>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Price)
# <Axes: xlabel='Price', ylabel='Density'>

# %%
sns.distplot(df.Longitude)
# Out:
# <ipython-input-28-815ae5648fd7>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Longitude)
# <Axes: xlabel='Longitude', ylabel='Density'>

# %%
sns.distplot(df.Lattitude)
# Out:
# <ipython-input-37-4790d4fed0b1>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Lattitude)
# <Axes: xlabel='Lattitude', ylabel='Density'>

# %%
sns.barplot(x=df.id.value_counts().index,y=df.id.value_counts())
# Out:
# <Axes: ylabel='id'>

# %%
sns.barplot(x=df.Longitude.value_counts().index,y=df.Longitude.value_counts())
# Out:
# <Axes: ylabel='Longitude'>

# %% [markdown]
# # **Bivariate Analysis**

# %%
sns.lineplot(x=df.Price,y=df.Price)
# Out:
# <Axes: xlabel='Price', ylabel='Price'>

# %%
sns.scatterplot(x=df.Price,y=df.Lattitude)
# Out:
# <Axes: xlabel='Price', ylabel='Lattitude'>

# %%
sns.lineplot(x=df.Price,y=df.Longitude)
# Out:
# <Axes: xlabel='Price', ylabel='Longitude'>

# %% [markdown]
# # **Multivariate Analysis**

# %%
sns.pairplot(df)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # Outlier detection

# %%
sns.boxplot(df.Lattitude)
# Out:
# <Axes: >

# %% [markdown]
# # Outlier Replacement - Median

# %%
q1 = df.Longitude.quantile
q3 = df.Longitude.quantile

# %%
print(q1)
print(q3)
# Out:
# <bound method Series.quantile of 0       -114.557
# 1       -114.470
# 2       -114.468
# 3       -114.321
# 4       -114.485
#           ...
# 14615   -114.472
# 14616   -114.393
# 14617   -114.507
# 14618   -114.411
# 14619   -114.552
# Name: Longitude, Length: 14620, dtype: float64>
# <bound method Series.quantile of 0       -114.557
# 1       -114.470
# 2       -114.468
# 3       -114.321
# 4       -114.485
#           ...
# 14615   -114.472
# 14616   -114.393
# 14617   -114.507
# 14618   -114.411
# 14619   -114.552
# Name: Longitude, Length: 14620, dtype: float64>

# %%
df.median()
# Out:
# id                                       6.762821e+09
# Date                                     4.260000e+04
# number of bedrooms                       3.000000e+00
# number of bathrooms                      2.250000e+00
# living area                              1.930000e+03
# lot area                                 7.620000e+03
# number of floors                         1.500000e+00
# waterfront present                       0.000000e+00
# number of views                          0.000000e+00
# condition of the house                   3.000000e+00
# grade of the house                       7.000000e+00
# Area of the house(excluding basement)    1.580000e+03
# Area of the basement                     0.000000e+00
# Built Year                               1.975000e+03
# Renovation Year                          0.000000e+00
# Postal Code                              1.220320e+05
# Lattitude                                5.280640e+01
# ...

# %%
sns.boxplot(df.id)
# Out:
# <Axes: >

# %% [markdown]
# Outlier Replacement - Median

# %% [markdown]
# Encoding Techniques

# %%
df.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %% [markdown]
# # Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df.Price = le.fit_transform(df.Price)
df.Lattitude= le.fit_transform(df.Lattitude)

# %%
df.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %% [markdown]
# # One hot encoding methods

# %% [markdown]
# # X and y split

# %%
X = df.drop(columns=['Price'],axis = 1)
X.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Area of the basement  Built Year  \
# ...

# %%
y = df.Price
y
# Out:
# 0        3289
# 1        3515
# 2        3491
# 3        4156
# 4        3679
#          ...
# 14615    1125
# 14616     236
# 14617    1992
# 14618    1865
# 14619     394
# Name: Price, Length: 14620, dtype: int64

# %% [markdown]
# # scaling

# %%
## Minmax Scaling

from sklearn.preprocessing import MinMaxScaler
scale =MinMaxScaler()

# %%
X_scaled= pd.DataFrame(scale.fit_transform(X),columns = X.columns)

# %%
X_scaled.head()
# Out:
#          id  Date  number of bedrooms  number of bathrooms  living area  \
# 0  0.005788   0.0             0.12500             0.266667     0.249051
# 1  0.028477   0.0             0.09375             0.266667     0.193622
# 2  0.045286   0.0             0.12500             0.300000     0.192863
# 3  0.119698   0.0             0.09375             0.266667     0.223235
# 4  0.134238   0.0             0.06250             0.200000     0.177677
#
#    lot area  number of floors  waterfront present  number of views  \
# 0  0.007945               0.4                 0.0              1.0
# 1  0.003241               0.2                 0.0              0.0
# 2  0.008345               0.2                 0.0              0.0
# 3  0.039562               0.4                 0.0              0.0
# 4  0.003707               0.2                 0.0              0.0
#
#    condition of the house  ...  Area of the basement  Built Year  \
# ...

# %% [markdown]
# Train Test Split

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(X_scaled,y,test_size=0.3,random_state = 0)

# %%
x_train.shape
# Out:
# (10234, 22)

# %%
y_train.shape
# Out:
# (10234,)

# %%
x_test.shape
# Out:
# (4386, 22)

# %%
y_test.shape
# Out:
# (4386,)
